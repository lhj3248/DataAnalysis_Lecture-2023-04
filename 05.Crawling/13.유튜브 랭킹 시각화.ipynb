# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('data/20230425_Youtube랭킹.csv')
df.head(3)
# Out:
#    순위      카테고리          채널명      구독자수          조회수   비디오
# 0   1  음악/댄스/가수    BLACKPINK  87300000  30533500000   507
# 1   2  음악/댄스/가수    BANGTANTV  74500000  20143000000  2188
# 2   3  음악/댄스/가수  HYBE LABELS  70300000  27323160000  1158

# %% [markdown]
# - 구독자수 Top 20

# %%
df = pd.read_csv('data/20230425_Youtube랭킹.csv')

# %%
plt.figure(figsize=(12,8))
plt.barh(df.채널명.head(20), df.구독자수.head(20))
plt.title('구독자수 Top 20 채널')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(y='채널명',x='구독자수',data=df.head(20))
plt.title('구독자수 Top 20 채널')
plt.show()

# %% [markdown]
# - 조회수 Top 20

# %%
plt.figure(figsize=(12,8))
sns.barplot(y='채널명',x='조회수',data=df.head(20))
plt.title('조회수 Top 20 채널')
plt.show()

# %%
df1 = df.head(20).sort_values(by='구독자수')
plt.figure(figsize=(12,8))
plt.barh(df1.채널명, df1.구독자수)
plt.title('구독자수 Top 20 채널')
plt.show()

# %% [markdown]
# - 비디오 수 Top 20

# %%
df2 = df1.sort_values(by= '비디오', ascending=False)
plt.figure(figsize=(12,7))
plt.barh(df2.채널명, df2.비디오)
plt.title('구독자수 Top 20 채널')
plt.show()

# %% [markdown]
# - 카테고리별 채널 수 Top 10

# %%
df3 =df.카테고리.value_counts().to_frame()
df3.head(10)
# Out:
#            count
# 카테고리
# 미분류          181
# 음악/댄스/가수     155
# 키즈/어린이       132
# TV/방송        125
# 음식/요리/레시피     71
# BJ/인물/연예인     61
# 뉴스/정치/사회      59
# 게임            51
# 취미/라이프        31
# 영화/만화/애니      30

# %%
sns.barplot(y=df3.index, x='count', data=df3);
plt.title('카테고리별 채널수 Top 10')
# Out:
# Text(0.5, 1.0, '카테고리별 채널수 Top 10')

# %% [markdown]
# - 카테고리별 구독자 수 Top 10

# %%
df4 = df.pivot_table('구독자수', '카테고리', aggfunc='sum').sort_values('구독자수', ascending=False)
df4.head(10)
# Out:
#                 구독자수
# 카테고리
# 음악/댄스/가수   818080000
# 키즈/어린이     402090000
# TV/방송      267760000
# 미분류        249330000
# 음식/요리/레시피  215100000
# 뉴스/정치/사회   102500000
# BJ/인물/연예인  102290000
# 게임          67350000
# 취미/라이프      49700000
# 영화/만화/애니    43950000

# %%
sns.barplot(y=df4.index[:10], x=df4.구독자수.head(10));
plt.title('카테고리별 채널수 Top 10')
# Out:
# Text(0.5, 1.0, '카테고리별 채널수 Top 10')
