# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
# pillow format의 img를 읽어서 중심부의 정사각형 이미지를 pillow format으로 반환
def center_image(img):
    h, w, _ = np.array(img).shape

# %%
img = Image.open('static/img/dead-lift.jpg')
plt.imshow(img), plt.axis('off');

# %%
np.array(img).shape
# Out:
# (168, 300, 3)

# %%
h, w, _ = np.array(img).shape

# %%
if h > w:
    width, height = w, w
else:
    width, height = h, h

# %%
diff = abs(h - w) // 2

# %%
if w > h:        # landscap image
    final_img = np.array(img)[:, diff:diff+h, :]
else:
    final_img = np.array(img)[diff:diff+w, :, :]

# %%
new_img = Image.fromarray(final_img)
plt.imshow(new_img)

# %%
import image_util as iu
plt.imshow(iu.center_image(img))

# %%
img.save('static/data/profile/')

# %%
iu.center_image
