# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# - Line graph

# %%
np.random.seed(2023)
df = pd.DataFrame(np.random.randn(100, 3), columns=list('ABC'),
                  index=pd.date_range('2023-04-01', periods=100)).cumsum()
df
# Out:
#                    A         B         C
# 2023-04-01  0.711674 -0.324485 -1.001871
# 2023-04-02  0.947924 -0.426645 -2.143163
# 2023-04-03  3.602332  1.013960 -2.044261
# 2023-04-04  0.480799 -0.062561 -2.369943
# 2023-04-05 -0.554698 -0.488882 -3.399304
# ...              ...       ...       ...
# 2023-07-05 -3.302478  0.956568 -1.160813
# 2023-07-06 -3.181638 -0.033662 -0.295832
# 2023-07-07 -3.848752 -1.480524  1.470245
# 2023-07-08 -3.083857 -0.267088  0.869608
# 2023-07-09 -4.489229 -0.993561 -0.100357
#
# [100 rows x 3 columns]

# %%
df.plot()           # default가 Line graph
plt.title('Pandas의 plot method 사용 예')
plt.xlabel('일자'), plt.ylabel('데이터')
plt.show()

# %% [markdown]
# - Bar chart

# %%
iris = sns.load_dataset('iris')
iris.sepal_length[:30].plot(kind='bar',figsize=(6,3))
plt.title('Iris Setosa 품종의 sepal length')
# Out:
# Text(0.5, 1.0, 'Iris Setosa 품종의 sepal length')

# %%
df2.plot.bar(rot=0, figsize=(6,3))
plt.title('Iris 품종별 Feature의 평균');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df2.plot.bar(rot=0, figsize=(6,3))
#       2 plt.title('Iris 품종별 Feature의 평균');
#
# NameError: name 'df2' is not defined

# %%
df.columns.name= 'Feature'
df2.plot.bar(rot=0, figsize=(6,3))
plt.ylim(0,10)                              # 범례가 차트와 겹치지않게
plt.title('Iris 품종별 Feature의 평균');

# %% [markdown]
# - Pie chart

# %%
titanic = sns.load_dataset('titanic')

s = titanic['class'].value_counts()
s
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
s.plot.pie(autopct='%2.f%%')
plt.title('선실별 승객수');

# %% [markdown]
# - histogram, kermel density

# %%
iris.plot.hist()
plt.subplot(122)
iris.plot.kde()
plt.show()
# Out:
# C:\Users\YONSAI\AppData\Local\Temp\ipykernel_10108\2709216206.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(122)

# %%
iris.plot(kde=)

# %% [markdown]
# - box plot

# %%
iris[iris.species == 'setosa']
plt.title('Iris setosa 품종의 각 피쳐별 Bot plot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 iris[iris.species == 'setosa']
#       2 plt.title('Iris setosa 품종의 각 피쳐별 Bot plot')
#
# NameError: name 'iris' is not defined

# %%
iris.boxplot(by='species')
plt.tight_layout()
plt.suptitle('Iris 각 피쳐의 품종별 박스 플롯')
# Out:
# Text(0.5, 0.98, 'Iris 각 피쳐의 품종별 박스 플롯')
