# %% [markdown]
# ### Folium 지도 시각화
# - 설치: pip.install folium

# %%
import folium
folium.__version__
# Out:
# '0.14.0'

# %%
map = folium.Map(location=[37.295, 127.045], zoom_start=14) # open Street map
folium.Marker(
    location=[37.2949837, 127.0453902],
    popup=folium.Popup('경기도 수원시 영통구 도청로 30', max_width=200),
    tooltip='경기도청'
).add_to(map)
map

# %%
map = folium.Map(location=[37.295, 127.045], zoom_start=14, tiles= step)
folium.Marker(
    location=[37.2949837, 127.0453902],
    popup=folium.Popup('경기도 수원시 영통구 도청로 30', max_width=200),
    tooltip='경기도청'
).add_to(map)
map

# %% [markdown]
# - 경기도청, 장안구청, 팔달구청, 권선구청, 영통구청

# %%
map = folium.Map(location=[37.295, 127.045], zoom_start=14) # open Street map
folium.Marker(
    location=[37.2949837,127.0453902],
    popup=folium.Popup('경기도 수원시 영통구 도청로 30', max_width=200),
    tooltip='경기도청',
    icon=folium.Icon(
    color='purple', icon_color='white',
    icon= 'glyphicon glyphicon-thumbs-up',  # 아이콘 제공 사이트

    prefix='glyphicon'
    )
).add_to(map)
folium.Marker(
    location=[37.30337225,127.0096118],
    popup=folium.Popup('경기도 수원시 장안구 송원로 101', max_width=200),
    tooltip='장안구청',
    icon=folium.Icon(color="green")
).add_to(map)

folium.Marker(
    location=[37.28256171,127.0190196],
    popup=folium.Popup('경기도 수원시 팔달구 창룡대로 23', max_width=200),
    tooltip='팔달구청',
    icon=folium.Icon(icon= "cloud", color="red")
).add_to(map)

folium.Circle(
    radius=300, color='crimson', fill=True,
    location=[37.25764489,126.9719386],
    popup=folium.Popup('경기도 수원시 권선구 호매실로 12', max_width=200),
    tooltip='권선구청'
    
).add_to(map)

folium.CircleMarker(
    radius=50, color='#3186cc', fill=True, fill_color='#3186cc',
    location=[37.2596127,127.0465469],
    popup=folium.Popup('경기도 수원시 영통구 효원로 407', max_width=200),
    tooltip='영통구청'
).add_to(map)
title_html = '<h3 align= "center" style="font-size:20px">  수원 소재 주요 관공서</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77aa0b559ba9cab75a2be626f550a024 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align= &quot;center&quot; style=&quot;font-size:20px&quot;&gt;  수원 소재 주요 관공서&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77aa0b559ba9cab75a2be626f550a024&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77aa0b559ba9cab75a2be626f550a024 = L.map(
#                 &quot;map_77aa0b559ba9cab75a2be626f550a024&quot;,
#                 {
#                     center: [37.295, 127.045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75e0d042e5aa82a865a87418e26b1c72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77aa0b559ba9cab75a2be626f550a024);
#
#
#             var marker_491771400166bdecee068e99aedb75af = L.marker(
#                 [37.2949837, 127.0453902],
#                 {}
#             ).addTo(map_77aa0b559ba9cab75a2be626f550a024);
#
#
#             var icon_a5caff5084dbcf4b372b22db17ef8a5b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_491771400166bdecee068e99aedb75af.setIcon(icon_a5caff5084dbcf4b372b22db17ef8a5b);
#
#
#         var popup_5a1d0ebe7730c881f711cd2a8041694e = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_53bedcbb11f22186ebf7a196e4d5e927 = $(`&lt;div id=&quot;html_53bedcbb11f22186ebf7a196e4d5e927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 영통구 도청로 30&lt;/div&gt;`)[0];
#                 popup_5a1d0ebe7730c881f711cd2a8041694e.setContent(html_53bedcbb11f22186ebf7a196e4d5e927);
#
#
#
#         marker_491771400166bdecee068e99aedb75af.bindPopup(popup_5a1d0ebe7730c881f711cd2a8041694e)
#         ;
#
#
#
#
#             marker_491771400166bdecee068e99aedb75af.bindTooltip(
#                 `&lt;div&gt;
#                      경기도청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a175f3e9f0ebdc53822b30785dd7c3e4 = L.marker(
#                 [37.30337225, 127.0096118],
#                 {}
#             ).addTo(map_77aa0b559ba9cab75a2be626f550a024);
#
#
#             var icon_a47a25cf7467ea1846f15c4d7194c956 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a175f3e9f0ebdc53822b30785dd7c3e4.setIcon(icon_a47a25cf7467ea1846f15c4d7194c956);
#
#
#         var popup_4c3afd0868bd3a27c3134c4ad854f3ef = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_7ccd52671986641c188656e224884205 = $(`&lt;div id=&quot;html_7ccd52671986641c188656e224884205&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 장안구 송원로 101&lt;/div&gt;`)[0];
#                 popup_4c3afd0868bd3a27c3134c4ad854f3ef.setContent(html_7ccd52671986641c188656e224884205);
#
#
#
#         marker_a175f3e9f0ebdc53822b30785dd7c3e4.bindPopup(popup_4c3afd0868bd3a27c3134c4ad854f3ef)
#         ;
#
#
#
#
#             marker_a175f3e9f0ebdc53822b30785dd7c3e4.bindTooltip(
#                 `&lt;div&gt;
#                      장안구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9b0e8448faccde455f13fa004cbbf668 = L.marker(
#                 [37.28256171, 127.0190196],
#                 {}
#             ).addTo(map_77aa0b559ba9cab75a2be626f550a024);
#
#
#             var icon_dbcfc3c5e32ce311dc4ff6a9a08f610c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b0e8448faccde455f13fa004cbbf668.setIcon(icon_dbcfc3c5e32ce311dc4ff6a9a08f610c);
#
#
#         var popup_f6b1bc26450d7b50444a585b7cefd810 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_f26c9d6f82a17bafebd0d3f09164ec88 = $(`&lt;div id=&quot;html_f26c9d6f82a17bafebd0d3f09164ec88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 팔달구 창룡대로 23&lt;/div&gt;`)[0];
#                 popup_f6b1bc26450d7b50444a585b7cefd810.setContent(html_f26c9d6f82
