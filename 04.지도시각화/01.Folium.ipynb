# %% [markdown]
# ### Folium 지도 시각화
# - 설치: pip.install folium

# %%
import folium
folium.__version__
# Out:
# '0.14.0'

# %%
map = folium.Map(location=[37.295, 127.045], zoom_start=14) # open Street map
folium.Marker(
    location=[37.2949837, 127.0453902],
    popup=folium.Popup('031-120', max_width=200),
    tooltip='경기도청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e9c204829007db45c1eb36dc443a9a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e9c204829007db45c1eb36dc443a9a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e9c204829007db45c1eb36dc443a9a5 = L.map(
#                 &quot;map_9e9c204829007db45c1eb36dc443a9a5&quot;,
#                 {
#                     center: [37.295, 127.045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f833bd9fecb53bdef52acc6c74c201bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e9c204829007db45c1eb36dc443a9a5);
#
#
#             var marker_7af2ad0a0bc81cdc874e1b33cadf2edd = L.marker(
#                 [37.2949837, 127.0453902],
#                 {}
#             ).addTo(map_9e9c204829007db45c1eb36dc443a9a5);
#
#
#         var popup_6877a1d2715225fd6e83bd33eabca31c = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_ffd7a49a05450c8716396f14a6305b3a = $(`&lt;div id=&quot;html_ffd7a49a05450c8716396f14a6305b3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;031-120&lt;/div&gt;`)[0];
#                 popup_6877a1d2715225fd6e83bd33eabca31c.setContent(html_ffd7a49a05450c8716396f14a6305b3a);
#
#
#
#         marker_7af2ad0a0bc81cdc874e1b33cadf2edd.bindPopup(popup_6877a1d2715225fd6e83bd33eabca31c)
#         ;
#
#
#
#
#             marker_7af2ad0a0bc81cdc874e1b33cadf2edd.bindTooltip(
#                 `&lt;div&gt;
#                      경기도청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.295, 127.045], zoom_start=14, tiles='Stamen Toner')
folium.Marker(
    location=[37.2949837, 127.0453902],     # WGS84 좌표계, 위도(latitude), 경도(longitude)
    popup=folium.Popup('경기도 수원시 영통구 도청로 30', max_width=200),
    tooltip='경기도청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ea01422597d811814d4e16494439c20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ea01422597d811814d4e16494439c20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ea01422597d811814d4e16494439c20 = L.map(
#                 &quot;map_2ea01422597d811814d4e16494439c20&quot;,
#                 {
#                     center: [37.295, 127.045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71eac5e4a3ab445930b2e5e0380d7f78 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ea01422597d811814d4e16494439c20);
#
#
#             var marker_81a8435d32b56dee7e74e0092d68b404 = L.marker(
#                 [37.2949837, 127.0453902],
#                 {}
#             ).addTo(map_2ea01422597d811814d4e16494439c20);
#
#
#         var popup_b1bcd07dd38b0358a7ca078f36a747df = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_dbc4abb74ea63f758ad1412d9e19f280 = $(`&lt;div id=&quot;html_dbc4abb74ea63f758ad1412d9e19f280&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 영통구 도청로 30&lt;/div&gt;`)[0];
#                 popup_b1bcd07dd38b0358a7ca078f36a747df.setContent(html_dbc4abb74ea63f758ad1412d9e19f280);
#
#
#
#         marker_81a8435d32b56dee7e74e0092d68b404.bindPopup(popup_b1bcd07dd38b0358a7ca078f36a747df)
#         ;
#
#
#
#
#             marker_81a8435d32b56dee7e74e0092d68b404.bindTooltip(
#                 `&lt;div&gt;
#                      경기도청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 경기도청, 장안구청, 팔달구청, 권선구청, 영통구청

# %%
map = folium.Map(location=[37.295, 127.045], zoom_start=14) # open Street map
folium.Marker(
    location=[37.2949837,127.0453902],
    popup=folium.Popup('031-120', max_width=200),
    tooltip='경기도청',
    icon=folium.Icon(
    color='purple', icon_color='white',
    icon= 'glyphicon glyphicon-thumbs-up',  # 아이콘 제공 사이트

    prefix='glyphicon'
    )
).add_to(map)
folium.Marker(
    location=[37.30337225,127.0096118],
    popup=folium.Popup('1899-3300', max_width=200),
    tooltip='장안구청',
    icon=folium.Icon(color="green")
).add_to(map)

folium.Marker(
    location=[37.28256171,127.0190196],
    popup=folium.Popup('1899-3300', max_width=200),
    tooltip='팔달구청',
    icon=folium.Icon(icon= "cloud", color="red")
).add_to(map)

folium.Circle(
    radius=300, color='crimson', fill=True,
    location=[37.25764489,126.9719386],
    popup=folium.Popup('1899-3300', max_width=200),
    tooltip='권선구청'
    
).add_to(map)

folium.CircleMarker(
    radius=50, color='#3186cc', fill=True, fill_color='#3186cc',
    location=[37.2596127,127.0465469],
    popup=folium.Popup('1899-3300', max_width=200),
    tooltip='영통구청'
).add_to(map)
title_html = '<h3 align= "center" style="font-size:20px">  수원 소재 주요 관공서</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4f988fbbba2286a9da6447e00533db9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align= &quot;center&quot; style=&quot;font-size:20px&quot;&gt;  수원 소재 주요 관공서&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4f988fbbba2286a9da6447e00533db9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4f988fbbba2286a9da6447e00533db9 = L.map(
#                 &quot;map_c4f988fbbba2286a9da6447e00533db9&quot;,
#                 {
#                     center: [37.295, 127.045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1ad905f66450e892fb9ab202bc490b0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4f988fbbba2286a9da6447e00533db9);
#
#
#             var marker_7c02312e6e8aae2cc5c5b6129f775523 = L.marker(
#                 [37.2949837, 127.0453902],
#                 {}
#             ).addTo(map_c4f988fbbba2286a9da6447e00533db9);
#
#
#             var icon_984a319e590140a4a430f5ddf2e3b2e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c02312e6e8aae2cc5c5b6129f775523.setIcon(icon_984a319e590140a4a430f5ddf2e3b2e3);
#
#
#         var popup_41cea0aa3cfeb2f250ad89bdbb2220d1 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_291d7a9fb002f1bf668fbfee2e13b4bb = $(`&lt;div id=&quot;html_291d7a9fb002f1bf668fbfee2e13b4bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 영통구 도청로 30&lt;/div&gt;`)[0];
#                 popup_41cea0aa3cfeb2f250ad89bdbb2220d1.setContent(html_291d7a9fb002f1bf668fbfee2e13b4bb);
#
#
#
#         marker_7c02312e6e8aae2cc5c5b6129f775523.bindPopup(popup_41cea0aa3cfeb2f250ad89bdbb2220d1)
#         ;
#
#
#
#
#             marker_7c02312e6e8aae2cc5c5b6129f775523.bindTooltip(
#                 `&lt;div&gt;
#                      경기도청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b8f0ac3d2bb7ea74ac6df464fae0b430 = L.marker(
#                 [37.30337225, 127.0096118],
#                 {}
#             ).addTo(map_c4f988fbbba2286a9da6447e00533db9);
#
#
#             var icon_d310763fbea677675734c11a57b97d4e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b8f0ac3d2bb7ea74ac6df464fae0b430.setIcon(icon_d310763fbea677675734c11a57b97d4e);
#
#
#         var popup_39243ac45ec5d6f728bd5461ad23fea2 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_3ddbf69188bbe4c8d707f8b105dfe336 = $(`&lt;div id=&quot;html_3ddbf69188bbe4c8d707f8b105dfe336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 장안구 송원로 101&lt;/div&gt;`)[0];
#                 popup_39243ac45ec5d6f728bd5461ad23fea2.setContent(html_3ddbf69188bbe4c8d707f8b105dfe336);
#
#
#
#         marker_b8f0ac3d2bb7ea74ac6df464fae0b430.bindPopup(popup_39243ac45ec5d6f728bd5461ad23fea2)
#         ;
#
#
#
#
#             marker_b8f0ac3d2bb7ea74ac6df464fae0b430.bindTooltip(
#                 `&lt;div&gt;
#                      장안구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bbe1cb0c55894495817976463be2b9a0 = L.marker(
#                 [37.28256171, 127.0190196],
#                 {}
#             ).addTo(map_c4f988fbbba2286a9da6447e00533db9);
#
#
#             var icon_23c611b75a5a19e5b58f2e2a5e5d3144 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbe1cb0c55894495817976463be2b9a0.setIcon(icon_23c611b75a5a19e5b58f2e2a5e5d3144);
#
#
#         var popup_89ab54ff5d9b3e2ba6d477e0e6812c08 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_951d903c28726c4bc664c850c8f98057 = $(`&lt;div id=&quot;html_951d903c28726c4bc664c850c8f98057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도 수원시 팔달구 창룡대로 23&lt;/div&gt;`)[0];
#                 popup_89ab54ff5d9b3e2ba6d477e0e6812c08.setContent(html_951d903c28
